# %%
using Revise
#using Plots
using GLMakie
using JLD2

pathBase = joinpath(@__DIR__, "../src/")


includet(pathBase * "RLEnvironment.jl")
includet(pathBase * "RLExperiment.jl")
includet(pathBase * "Visualization.jl")

includet(pathBase * "Misc.jl")
includet(pathBase * "SharedStructs.jl")
using .SharedStructs

# %%
# set default parameters
parameters = Dict(
# grid params
"domainType" => "cyl",
"Nx" => 150,
"Ny" => 1,
"dx" => 1.0,
"dt" => 2e-4,
"ndt" => 1000,
"timeStride" => 1,
"startCollecting" => 0,
"seed" => 0,
    
# boundary conditions
"bcU_X" => "neuCyl",
"bcU_Y" => "neu",

"bcRAD_X" => "neuCyl",
"bcRAD_Y" => "neu",

# chemical parameters
"kAct" => 5e1,
"kInact" => 5e0,
"kTrap" => 3e2,
"kRel" => 7e2,
"kIBind" => 1e-1,
"kIUnbind" => 1e0,
"kABind" => 1e-1,
"kAUnbind" => 0,
"beta" => 1.0,
"CSat" => 5,
    
"DT" => 1,
"DD" => 25,
"DC" => 500,
    
"CDI0" => 2.5,
"CDA0" => 0,
"CBI0" => 0.1,
"CBA0" => 0,
"CC0" => 0,
"CD0" => 20,
"CDst0" => 20,

"lambda0" => 3.0,
"mu0" => 3.0,
"gMin" => 0.5,
    
## reward params
"ust" => -0.25,
"rst" => 75,

## parameters of the Environment object
"nSteps" => 100, # number of steps in one episode
"bounds" => [1.0, 15.0, 5.0], # range of allowed increments of the activityCoefficients
"rewP" => 1, # strength of the penalty used to compute the reward
    
## parameters of the Experiment object
"eps_or_hrs" => "eps", # terminate after nEpisodes epsiodes ("eps") or nEpisodes hours ("hrs")
"nEpisodes" => 1, # number of episodes / hours
"stepStride" => 1,
"episodeStride" => 1,
"stateTrajStride" => 1,
"batchSize" => 128, # how many samples to include in replay buffer used to train the networks
"updateFreq" => 10, # how many steps to do before updating the network parameters 
"netLayers" => 1,
"netWidth" => 32,
"gamma" => 0.99f0, 
"rho" => 0.9995f0,
    
"act_limit" => 1.0,
"act_noise" => 0e-1,
"annealBool" => false,
"annealTime" => 250,

## restart parameters
"restartBool" => false, # whether to load experiment from a previous SavedData file or not 
"parentDirectoryName" => "Dirs_ks_cutoff", # the name of the parent folder containing all the param trials
"restartLabel" => "_R" # the label which has been appended to parentDirectoryName directory manually by the user
);

println("Done.")
# Out:
# Done.

# %%
@time ex = InitializeAndRunExperiment(parameters)
# Out:
# Initializing...
#   TCB2 RL with DDPG
#   ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
#  63.053012 seconds (191.26 M allocations: 36.706 GiB, 10.94% gc time, 41.31% compilation time: <1% of which was recompilation)
#   TCB2 RL with DDPG
#   ≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡≡
# typename(Experiment)
# ├─ policy => typename(Agent)
# │  ├─ policy => typename(DDPGPolicy)
# │  │  ├─ behavior_actor => typename(NeuralNetworkApproximator)
# │  │  │  ├─ model => typename(Chain)
# │  │  │  │  └─ layers
# │  │  │  │     ├─ 1
# │  │  │  │     │  └─ typename(Dense)
# │  │  │  │     │     ├─ weight => 32×1 Matrix{Float32}
# │  │  │  │     │     ├─ bias => 32-element Vector{Float32}
# │  │  │  │     │     └─ σ => typename(typeof(relu))
# │  │  │  │     ├─ 2
# │  │  │  │     │  └─ typename(Dense)
# │  │  │  │     │     ├─ weight => 32×32 Matrix{Float32}
# │  │  │  │     │     ├─ bias => 32-element Vector{Float32}
# │  │  │  │     │     └─ σ => typename(typeof(relu))
# │  │  │  │     └─ 3
# │  │  │  │        └─ typename(Dense)
# │  │  │  │           ├─ weight => 3×32 Matrix{Float32}
# │  │  │  │           ├─ bias => 3-element Vector{Float32}
# │  │  │  │           └─ σ => typename(typeof(identity))
# │  │  │  └─ optimizer => typename(Flux.Optimise.Optimiser)
# │  │  │     └─ os => 2-element Vector{Any}
# │  │  ├─ behavior_critic => typename(NeuralNetworkApproximator)
# │  │  │  ├─ model => typename(Chain)
# │  │  │  │  └─ layers
# │  │  │  │     ├─ 1
# │  │  │  │     │  └─ typename(Dense)
# │  │  │  │     │     ├─ weight => 32×4 Matrix{Float32}
# │  │  │  │     │     ├─ bias => 32-element Vector{Float32}
# │  │  │  │     │     └─ σ => typename(typeof(relu))
# │  │  │  │     ├─ 2
# │  │  │  │     │  └─ typename(Dense)
# │  │  │  │     │     ├─ weight => 32×32 Matrix{Float32}
# │  │  │  │     │     ├─ bias => 32-element Vector{Float32}
# │  │  │  │     │     └─ σ => typename(typeof(relu))
# │  │  │  │     └─ 3
# │  │  │  │        └─ typename(Dense)
# │  │  │  │           ├─ weight => 1×32 Matrix{Float32}
# │  │  │  │           ├─ bias => 1-element Vector{Float32}
# │  │  │  │           └─ σ => typename(typeof(identity))
# │  │  │  └─ optimizer => typename(Flux.Optimise.Optimiser)
# │  │  │     └─ os => 2-element Vector{Any}
# │  │  ├─ target_actor => typename(NeuralNetworkApproximator)
# │  │  │  ├─ model => typename(Chain)
# │  │  │  │  └─ layers
# │  │  │  │     ├─ 1
# │  │  │  │     │  └─ typename(Dense)
# │  │  │  │     │     ├─ weight => 32×1 Matrix{Float32}
# │  │  │  │     │     ├─ bias => 32-element Vector{Float32}
# │  │  │  │     │     └─ σ => typename(typeof(relu))
# │  │  │  │     ├─ 2
# │  │  │  │     │  └─ typename(Dense)
# │  │  │  │     │     ├─ weight => 32×32 Matrix{Float32}
# │  │  │  │     │     ├─ bias => 32-element Vector{Float32}
# │  │  │  │     │     └─ σ => typename(typeof(relu))
# │  │  │  │     └─ 3
# │  │  │  │        └─ typename(Dense)
# │  │  │  │           ├─ weight => 3×32 Matrix{Float32}
# │  │  │  │           ├─ bias => 3-element Vector{Float32}
# │  │  │  │           └─ σ => typename(typeof(identity))
# │  │  │  └─ optimizer => typename(Nothing)
# │  │  ├─ target_critic => typename(NeuralNetworkApproximator)
# │  │  │  ├─ model => typename(Chain)
# │  │  │  │  └─ layers
# │  │  │  │     ├─ 1
# │  │  │  │     │  └─ typename(Dense)
# │  │  │  │     │     ├─ weight => 32×4 Matrix{Float32}
# │  │  │  │     │     ├─ bias => 32-element Vector{Float32}
# │  │  │  │     │     └─ σ => typename(typeof(relu))
# │  │  │  │     ├─ 2
# │  │  │  │     │  └─ typename(Dense)
# │  │  │  │     │     ├─ weight => 32×32 Matrix{Float32}
# │  │  │  │     │     ├─ bias => 32-element Vector{Float32}
# │  │  │  │     │     └─ σ => typename(typeof(relu))
# │  │  │  │     └─ 3
# │  │  │  │        └─ typename(Dense)
# │  │  │  │           ├─ weight => 1×32 Matrix{Float32}
# │  │  │  │           ├─ bias => 1-element Vector{Float32}
# │  │  │  │           └─ σ => typename(typeof(identity))
# │  │  │  └─ optimizer => typename(Nothing)
# │  │  ├─ γ => 0.99
# │  │  ├─ ρ => 0.9995
# │  │  ├─ na => 3
# │  │  ├─ batch_size => 128
# │  │  ├─ start_steps => 1
# │  │  ├─ start_policy => typename(RandomPolicy)
# │  │  │  ├─ action_space => typename(Space)
# │  │  │  │  └─ s => 3-element Vector{ClosedInterval{Float64}}
# │  │  │  └─ rng => typename(StableRNGs.LehmerRNG)
# │  │  ├─ update_after => 1
# │  │  ├─ update_freq => 10
# │  │  ├─ act_limit => 1.0
# │  │  ├─ act_noise => 0.0
# │  │  ├─ update_step => 101
# │  │  ├─ rng => typename(StableRNGs.LehmerRNG)
# │  │  ├─ actor_loss => -0.3764454
# │  │  └─ critic_loss => 0.032232296
# │  └─ trajectory => typename(Trajectory)
# │     └─ traces => typename(NamedTuple)
# │        ├─ state => 1×102 CircularArrayBuffers.CircularArrayBuffer{Float64, 2, Matrix{Float64}}
# │        ├─ action => 3×102 CircularArrayBuffers.CircularArrayBuffer{Float64, 2, Matrix{Float64}}
# │        ├─ reward => 101-element CircularArrayBuffers.CircularVectorBuffer{Float32, Vector{Float32}}
# │        └─ terminal => 101-element CircularArrayBuffers.CircularVectorBuffer{Bool, Vector{Bool}}
# ├─ env => typename(TCB2Env)
# ├─ stop_condition => typename(StopAfterEpisode)
# │  ├─ episode => 1
# │  ├─ cur => 1
# │  └─ progress => typename(ProgressMeter.Progress)
# ├─ hook => typename(RLTCB2Hook)
# │  ├─ episodeList => 1-element Vector{EpisodeInformation}
# │  ├─ stateTrajList => 1-element Vector{Any}
# │  ├─ actorLossList => 1-element Vector{Real}
# │  ├─ criticLossList => 1-element Vector{Real}
# │  ├─ storingBool => true
# │  ├─ stateTrajBool => true
# │  ├─ stepStride => 1
# │  ├─ stepCount => 101
# │  ├─ episodeStride => 1
# │  ├─ stateTrajStride => 1
# │  └─ episodeCount => 1
# └─ description => "# TCB2 RL with DDPG"

# %%
Makie.lines(ex.env.sS.dF.uxSoA.Values[1:end])

# %%
Makie.lines(ex.hook.stateTrajList[1][end].gammaSoA.Values[1:end])

# %%
Makie.lines(ex.hook.stateTrajList[1][end].dF.uxSoA.Values[1:end])

# %%
30 * 1000 / 3600
# Out:
# 8.333333333333334
